# %% [markdown]
# <a href="https://colab.research.google.com/github/izabellabronowskawsti-eng/machine-learning-bootcamp/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello Colab')
# Out:
# Hello Colab
